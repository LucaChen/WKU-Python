# %% [markdown]
# # 取名的重要性——给各类型数据取名方便项目开展
#
# ## 任务九：将两个单词或两段话组合成一句话
#
# &emsp;&emsp;在这个项目中，我们需要将 `人格解体` 和 `角色扮演` 两个字符串连接起来。但是，字符串和数字不一样，在我们生活中，数字的累加都能理解，但是字符串之间该如何串联起来？
#
# &emsp;&emsp;其实，在 `Python` 中，需要将两个或多个不同的字符串串联时，可以使用 `+` 运算符将它们链接在一起：
#
# ```python
# print('人格解体' + '角色扮演')
# ```
#
# &emsp;&emsp;我们在下方代码块中尝试一下。

# %%
# 练习区域

# %% [markdown]
# &emsp;&emsp;这两个字符串确实被连接起来了，不过为了易读，可以在 `2` 个字符串之间加入一个空格：
#
# ```python
# print('人格解体' + ' ' + '角色扮演')
# ```

# %%
# 练习区域

# %% [markdown]
# &emsp;&emsp;我们拓展一下，既然数字也可以被当做字符，那字符形式的数字是否可以和数字形式的数字相加呢？我们可以来测试一下：
#
# ```python
# print('5' + 5)
# ```

# %%
# 练习区域

# %% [markdown]
# &emsp;&emsp;报错了，这回是类型错误：`TypeError: must be str, not int`。
#
# &emsp;&emsp;这也就意味着，只有相同类型之间可以相加。试想，我们是不是可以先将不同类型转换为相同类型，然后再将转换成数字类型的数据相加，联想到前面的任务中曾经提到过将整数类型的数字转换成浮点数类型，那是否可以将整数类型转换为字符？
#
# &emsp;&emsp;确实是有的，我们可以使用 `int()` 或者 `float()` 将字符或字符串的数字转换为整数类型或浮点数类型的数字，也可以用 `str()` 将 `int` 整数类型或 `float` 浮点数类型的数字转换成字符或字符串类型。我们可以来测试一下：
#
# ```python
# print(int('5') + 5)
# ```

# %%
# 练习区域

# %% [markdown]
# ### 练习
#
# 1. 将字符串 `人格解体's score is` 赋值给变量 `score` 并输出打印
#
# 2. 将浮点数 `8.8` 赋值给 `score` 并输出打印
#
# 3. 通过组合，输出打印 `人格解体's score is 8.8` 这句话。

# %%
# 练习区域
