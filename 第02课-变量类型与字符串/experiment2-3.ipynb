# %% [markdown]
# # 取名的重要性——给各类型数据取名方便项目开展
#
# ## 任务三：修改名称中的数据
#
# &emsp;&emsp;在任务一的最后，我们曾提出过质疑 “我们在之前就已经对 `data` 赋值了 `36`，那刚刚 输出的 `36` 真的是 `(2 + 7) * 4` 的计算结果吗？”
#
# &emsp;&emsp;当时我们在任务一的练习中实际感受了这个质疑，即通过两次不同的赋值来查看：
#
# ``` python
# data = (2 + 7) * 4
# print(data)
# data = (56 + 86) / 54
# print(data)
# ```

# %%
# 练习区域

# %% [markdown]
# &emsp;&emsp;对于 `data` 这个变量，我们先存储了 `36`，又将其用 `2.6296296296296298` 覆盖了，说明变量是可以被更新的。
#
# &emsp;&emsp;现在，我们已经知道变量是可以被更新的，同时变量是可以代表数字的，那是否可以将原有的算术运算用若干变量来代替呢？
#
# &emsp;&emsp;我们尝试一下：
#
# ```python
# data = (2 + 7) * 4
# print(data)
# data = data + 1
# print(data)
# ```

# %%
# 练习区域

# %% [markdown]
# &emsp;&emsp;注意上面的代码中：
#
# - 变量 `data` 最初存储的值为 `36`。
# - 当我们运行 `data = data + 1` 时，`data` 将存储的信息从 `36` 更新到了 `37`。
# - `print(data)` 的运行结果自然就变成了 `37`。

# %% [markdown]
# ### 练习
#
# 1. 对变量 `you` 赋值为 `2`，输出后通过算术计算，将其更新为 `20`。

# %%
# 练习区域
